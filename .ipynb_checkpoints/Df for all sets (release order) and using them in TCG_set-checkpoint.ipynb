# %%
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import re
import os
import cardmarket_singles_parsing as csm
from TCG_set_V4 import TCG_set
import shutil

# %%
#want to enter the above df and then get back the df with a column full of set codes.

def set_code(dataframe):
    
    
    code_list = []
    for i in range(0,len(dataframe)):
        url = dataframe['Yugipedia url'][i]
        print(url)
        result = requests.get(url)
        src = result.content
        soup = BeautifulSoup(src, 'html.parser')
        
        card_info_headers = soup.find_all(attrs = {'class':'set-list'})
        
        if card_info_headers[0].find('td').text[0:4] == '25TH':
            code = 'BACH'
        elif card_info_headers[0].find('td').text[0:4] == '\"Blu':
            code = 'DUOV'
        else:
            code = card_info_headers[0].find('td').text
            code = code[0:4]
            
        if code[3] == '-':
            code = code[0:3]
            
        print(code)
        code_list.append(code)
    
    dataframe['Set Code'] = code_list
    return dataframe

# %%
url = "https://yugipedia.com/wiki/Order_of_Set_Release#2022_2"
result = requests.get(url)
src = result.content
soup = BeautifulSoup(src, 'html.parser')

sets_dfs = []
for i in range(0,21):
    
    if i == 0:
        TCG_set_name = []
        TCG_set_yugipedia_link = []

        for TCG_card_set in soup.find_all("ul")[339:345]:
            set_names = TCG_card_set.find_all('a')
            for set_name in set_names:
                TCG_set_name.append(set_name.text)
                TCG_set_yugipedia_link.append('https://yugipedia.com' + set_name.attrs['href'])

        df = pd.DataFrame({"Set Name" : TCG_set_name, "Yugipedia url" : TCG_set_yugipedia_link})
        sets_dfs.append(df)

    elif i == 1:
        TCG_set_name = []
        TCG_set_yugipedia_link = []

        for TCG_card_set in soup.find_all("ul")[345:354]:
            set_names = TCG_card_set.find_all('a')
            for set_name in set_names:
                TCG_set_name.append(set_name.text)
                TCG_set_yugipedia_link.append('https://yugipedia.com' + set_name.attrs['href'])

        df = pd.DataFrame({"Set Name" : TCG_set_name, "Yugipedia url" : TCG_set_yugipedia_link})
        sets_dfs.append(df)
    
    elif 1 < i < 4:
        TCG_set_name = []
        TCG_set_yugipedia_link = []

        for TCG_card_set in soup.find_all("ul")[354 + 12*(i-2): 354+ 12*(i-1)]:
            set_names = TCG_card_set.find_all('a')
            for set_name in set_names:
                TCG_set_name.append(set_name.text)
                TCG_set_yugipedia_link.append('https://yugipedia.com' + set_name.attrs['href'])

        df = pd.DataFrame({"Set Name" : TCG_set_name, "Yugipedia url" : TCG_set_yugipedia_link})
        sets_dfs.append(df)
        
    elif i == 4:
        TCG_set_name = []
        TCG_set_yugipedia_link = []

        for TCG_card_set in soup.find_all("ul")[354 + 12*(i-2): 354+ 12*(i-2)+11]:
            set_names = TCG_card_set.find_all('a')
            for set_name in set_names:
                TCG_set_name.append(set_name.text)
                TCG_set_yugipedia_link.append('https://yugipedia.com' + set_name.attrs['href'])

        df = pd.DataFrame({"Set Name" : TCG_set_name, "Yugipedia url" : TCG_set_yugipedia_link})
        sets_dfs.append(df)
    elif 4 < i < 19:
        TCG_set_name = []
        TCG_set_yugipedia_link = []

        for TCG_card_set in soup.find_all("ul")[389 + 12*(i-5): 389 + 12*(i-4)]:
            set_names = TCG_card_set.find_all('a')
            for set_name in set_names:
                TCG_set_name.append(set_name.text)
                TCG_set_yugipedia_link.append('https://yugipedia.com' + set_name.attrs['href'])

        df = pd.DataFrame({"Set Name" : TCG_set_name, "Yugipedia url" : TCG_set_yugipedia_link})
        sets_dfs.append(df)
    elif i == 19:
        TCG_set_name = []
        TCG_set_yugipedia_link = []

        for TCG_card_set in soup.find_all("ul")[567: 578]:
            set_names = TCG_card_set.find_all('a')
            for set_name in set_names:
                TCG_set_name.append(set_name.text)
                TCG_set_yugipedia_link.append('https://yugipedia.com' + set_name.attrs['href'])

        df = pd.DataFrame({"Set Name" : TCG_set_name, "Yugipedia url" : TCG_set_yugipedia_link})
        sets_dfs.append(df)
    else:
        print(i)
        TCG_set_name = []
        TCG_set_yugipedia_link = []

        for TCG_card_set in soup.find_all("ul")[580 + 12*(i-20): 580 + 12*(i-19)]:
            set_names = TCG_card_set.find_all('a')
            for set_name in set_names:
                TCG_set_name.append(set_name.text)
                TCG_set_yugipedia_link.append('https://yugipedia.com' + set_name.attrs['href'])

        df = pd.DataFrame({"Set Name" : TCG_set_name, "Yugipedia url" : TCG_set_yugipedia_link})
        sets_dfs.append(df)
        
year_set_dict = {[str(2002 + i) for i in range(0,21)][i] : sets_dfs[i] for i in range(0,21)}
# Out:
# 20

# %%
year_set_dict['2021']
# Out:
#                                              Set Name  \
# 0                                  The Grand Creators
# 1                                     Battle of Chaos
# 2                              OTS Tournament Pack 18
# 3                           Hidden Arsenal: Chapter 1
# 4               Speed Duel Box featuring Yu-Gi-Oh! GX
# 5                        Speed Duel Tournament Pack 3
# 6   Trials of the Pharaoh - Speed Duel GX: Duel Ac...
# 7   Japan Championship 2022 Shop Qualifiers prize ...
# 8                        Structure Deck: Albaz Strike
# 9              Ghosts From the Past: The 2nd Haunting
# 10                                    Dimension Force
# 11                             OTS Tournament Pack 19
# 12            Legendary Duelists: Duels From the Deep
# 13                       Legendary Duelists: Season 3
# 14                              Power of the Elements
# 15                                   Tactical Masters
# 16                KC Grand Tournament 2022 prize card
# 17      Yu-Gi-Oh! Championship Series 2022 prize card
# 18                     2022 Tin of the Pharaoh's Gods
# 19                       Speed Duel Tournament Pack 4
# 20       Structure Deck: Legend of the Crystal Beasts
# 21                             OTS Tournament Pack 20
# 22                     Speed Duel GX: Midterm Paradox
# 23                                     Darkwing Blast
# 24                                 Magnificent Mavens
# 25                 Battles of Legend: Crystal Revenge
#
#                                         Yugipedia url
# 0       https://yugipedia.com/wiki/The_Grand_Creators
# 1          https://yugipedia.com/wiki/Battle_of_Chaos
# 2   https://yugipedia.com/wiki/OTS_Tournament_Pack_18
# 3   https://yugipedia.com/wiki/Hidden_Arsenal:_Cha...
# 4   https://yugipedia.com/wiki/Speed_Duel_Box_feat...
# 5   https://yugipedia.com/wiki/Speed_Duel_Tourname...
# 6   https://yugipedia.com/wiki/Trials_of_the_Phara...
# 7   https://yugipedia.com/wiki/Japan_Championship_...
# 8   https://yugipedia.com/wiki/Structure_Deck:_Alb...
# 9   https://yugipedia.com/wiki/Ghosts_From_the_Pas...
# 10         https://yugipedia.com/wiki/Dimension_Force
# 11  https://yugipedia.com/wiki/OTS_Tournament_Pack_19
# 12  https://yugipedia.com/wiki/Legendary_Duelists:...
# 13  https://yugipedia.com/wiki/Legendary_Duelists:...
# 14   https://yugipedia.com/wiki/Power_of_the_Elements
# 15        https://yugipedia.com/wiki/Tactical_Masters
# 16  https://yugipedia.com/wiki/KC_Grand_Tournament...
# 17  https://yugipedia.com/wiki/Yu-Gi-Oh!_Champions...
# 18  https://yugipedia.com/wiki/2022_Tin_of_the_Pha...
# 19  https://yugipedia.com/wiki/Speed_Duel_Tourname...
# 20  https://yugipedia.com/wiki/Structure_Deck:_Leg...
# 21  https://yugipedia.com/wiki/OTS_Tournament_Pack_20
# 22  https://yugipedia.com/wiki/Speed_Duel_GX:_Midt...
# 23          https://yugipedia.com/wiki/Darkwing_Blast
# 24      https://yugipedia.com/wiki/Magnificent_Mavens
# 25  https://yugipedia.com/wiki/Battles_of_Legend:_...

# %%
years = [str(2002 + i) for i in range(0,21)]
years_2012_2021 = [str(2002 + i) for i in range(10,20)]
set_code_dfs = []
for year in years_2012_2021:
    
    df = year_set_dict[year]
    
    sets_done_index = []
    
    for i in range(0, len(df)):
        if ('KC Grand Tournament' in list(df['Set Name'])[i]) or ('Japan Championship' in list(df['Set Name'])[i]) or ('Masterpiece Series' in list(df['Set Name'])[i]) or ('Premiere! promotional card' in list(df['Set Name'])[i]) or ('Sneak Peek Participation Card' in list(df['Set Name'])[i]) or ('Special Edition' in list(df['Set Name'])[i]) or ('Super Edition' in list(df['Set Name'])[i]) or ('Custom Token' in list(df['Set Name'])[i]) or ('Value Box' in list(df['Set Name'])[i]) or ('Beginner\'s Kit'  in list(df['Set Name'])[i]): 
            sets_done_index.append(i)
    
    df = df.drop(sets_done_index)
    df = df.reset_index(drop = True)
    
    set_code_df = set_code(df)
    set_code_dfs.append(set_code_df)

#2 has set codes as well
year_set_dict_2 = {years_2012_2021[i] : set_code_dfs[i] for i in range(0,len(set_code_dfs))}
# Out:
# 0
# https://yugipedia.com/wiki/Dragunity_Blast
# SDDL-EN001
# SDDL
# 1
# https://yugipedia.com/wiki/Turbo_Pack:_Booster_Seven
# TU07-EN000
# TU07
# 2
# https://yugipedia.com/wiki/Yu-Gi-Oh!_GX_Volume_8_promotional_card
# YG08-EN001
# YG08
# 3
# https://yugipedia.com/wiki/Order_of_Chaos
# ORCS-EN000
# ORCS
# 4
# https://yugipedia.com/wiki/Duel_Terminal_6a
# DT06-EN001
# DT06
# 5
# https://yugipedia.com/wiki/Dragons_Collide_Structure_Deck
# SDDC-EN001
# SDDC
# 6
# https://yugipedia.com/wiki/Yu-Gi-Oh!_5D%27s_Volume
# https://yugipedia.com/wiki/Weekly_Shonen_Jump_Alpha_December_2012_membership_promotional_card
# JUMP-EN063
# JUMP
# 0
# https://yugipedia.com/wiki/Collectible_Tins_2012_Wave_2.5
# CT09-EN019
# CT09
# 1
# https://yugipedia.com/wiki/Cosmo_Blazer
# CBLZ-EN000
# CBLZ
# 2
# https://yugipedia.com/wiki/Duel_Terminal_7b
# DT07-EN051
# DT07
# 3
# https://yugipedia.com/wiki/Onslaught_of_the_Fire_Kings_Structure_Deck
# SDOK-EN001
# SDOK
# 4
# https://yugipedia.com/wiki/Star_Pack_2013
# SP13-EN001
# SP13
# 5
# https://yugipedia.com/wiki/Zexal_Collection_Tin
# ZTIN-ENV01
# ZTIN
# 6
# https://yugipedia.com/wiki/Weekly_Shonen_Jump_March_2013_membership_promotional_card
# JUMP-EN064
# JUMP
# 7
# https://yugipedia.com/wiki/Yu-Gi-Oh!_5D%27s_Volume_4_promotional_card
# YF04-EN001
# YF04
# 8
# https://yugipedia.com/wiki/Astral_Pack_Two
# AP02-EN001
# AP02
# 9
# https://yugipedia.com/wiki/Hidden_Arsenal_7:_Knight_of_Stars
# HA07-EN001
# HA07
# 10
# https://yugipedia.com/wiki/Legendary_Collection_2:_Gameboard_Edition
# LC02-EN001
# LC02
# 11
# https://yugipedia.com/wiki/Lord_of_the_Tachyon_Galaxy
# LTGY-EN000
# LTGY
# 12
# https://yugipedia.com/wiki/Yu-Gi-Oh!_ZEXAL_Volume_3_promotional_card
# YZ03-EN001
# YZ03
# 13
# https://yugipedia.com/wiki/Super_Starter:_V_for_Victory
# YS13-EN001
# YS13
# 14
# https://yugipedia.com/wiki/Super_Starter_Power-Up_Pack
# YS13-ENV01
# YS13
# 15
# https://yugipedia.com/wiki/Battle_Pack_2:_War_of_the_Giants
# BP02-EN001
# BP02
# 16
# https://yugipedia.com/wiki/Duelist_League_16_participation_cards
# DL16-EN001
# DL16
# 17
# https://yugipedia.com/wiki/Weekly_Shonen_Jump_July_2013_membership_promotional_card
# JUMP-EN065
# JUMP
# 18
# https://yugipedia.com/wiki/Number_Hunters
# NUMH-EN001
# NUMH
# 19
# https://yugipedia.com/wiki/Judgment_of_the_Light
# JOTL-EN000
# JOTL
# 20
# https://yugipedia.com/wiki/Yu-Gi-Oh!_World_Championship_2013_prize_cards
# 2013-EN001
# 2013
# 21
# https://yugipedia.com/wiki/2013_Collectible_Tins_Wave_1
# CT10-EN001
# CT10
# 22
# https://yugipedia.com/wiki/Yu-Gi-Oh!_Championship_Series_2013_Prize_Card
# YCSW-EN006
# YCSW
# 23
# https://yugipedia.com/wiki/Saga_of_Blue-Eyes_White_Dragon_Structure_Deck
# SDBE-EN001
# SDBE
# 24
# https://yugipedia.com/wiki/Astral_Pack_Three
# AP03-EN001
# AP03
# 25
# https://yugipedia.com/wiki/Legendary_Collection_4:_Joey%27s_World
# LC04-EN001
# LC04
# 26
# https://yugipedia.com/wiki/Legendary_Collection_4:_Joey%27s_World_Mega_Pack
# LCJW-EN001
# LCJW
# 27
# https://yugipedia.com/wiki/Weekly_Shonen_Jump_September_2013_membership_promotional_card
# JUMP-EN066
# JUMP
# 28
# https://yugipedia.com/wiki/Yu-Gi-Oh!_5D%27s_Volume_5_promotional_card
# YF05-EN001
# YF05
# 29
# https://yugipedia.com/wiki/Shadow_Specters
# SHSP-EN000
# SHSP
# 30
# https://yugipedia.com/wiki/Legendary_Collection:_Gameboard_Edition
# LC01-EN001
# LC01
# 31
# https://yugipedia.com/wiki/2013_Collectible_Tins_Wave_2
# CT10-EN003
# CT10
# 32
# https://yugipedia.com/wiki/Starter_Deck:_Yugi_Reloaded
# YSYR-EN001
# YSYR
# 33
# https://yugipedia.com/wiki/Starter_Deck:_Kaiba_Reloaded
# YSKR-EN001
# YSKR
# 34
# https://yugipedia.com/wiki/Duelist_League_17_participation_cards
# DL17-EN001
# DL17
# 35
# https://yugipedia.com/wiki/Weekly_Shonen_Jump
# https://yugipedia.com/wiki/Weekly_Shonen_Jump_November_2014_membership_promotional_card
# JUMP-EN070
# JUMP
# 31
# https://yugipedia.com/wiki/Geargia_Rampage_Structure_Deck
# SDGR-EN001
# SDGR
# 32
# https://yugipedia.com/wiki/Legendary_Collection_5D%27s
# LC05-EN001
# LC05
# 33
# https://yugipedia.com/wiki/Legendary_Collection_5D%27s_Mega_Pack
# LC5D-EN001
# LC5D
# 34
# https://yugipedia.com/wiki/The_New_Challengers
# NECH-EN000
# NECH
# 35
# https://yugipedia.com/wiki/Noble_Knights_of_the_Round_Table_Box_Set
# NKRT-EN001
# NKRT
# 36
# https://yugipedia.com/wiki/Noble_Knights_of_the_Round_Table_Power-Up_Pack
# NKRT-EN039
# NKRT
# 37
# https://yugipedia.com/wiki/Astral_Pack_Six
# AP06-EN001
# AP06
# 0
# https://yugipedia.com/wiki/Secrets_of_Eternity
# SECE-EN000
# SECE
# 1
# https://yugipedia.com/wiki/HERO_Strike_Structure_Deck
# SDHS-EN001
# SDHS
# 2
# https://yugipedia.com/wiki/Yu-Gi-Oh!_ZEXAL_Volume_6_promotional_card
# YZ06-EN001
# YZ06
# 3
# https://yugipedia.com/wiki/The_Secret_Forces
# THSF-EN001
# THSF
# 4
# https://yugipedia.com/wiki/Weekly_Shonen_Jump_February_2015_membership_promotional_card
# JUMP-EN071
# JUMP
# 5
# https://yugipedia.com/wiki/Yu-Gi-Oh!_5D%27s_Volume_7_promotional_card
# YF07-EN001
# YF07
# 6
# https://yugipedia.com/wiki/Premium_Gold:_Return_of_the_Bling
# PGL2-EN001
# PGL2
# 7
# https://yugipedia.com/wiki/Demo_Deck_2015
# DEM2-EN001
# DEM2
# 8
# https://yugipedia.com/wiki/World_Superstars
# WSUP-EN001
# WSUP
# 9
# https://yugipedia.com/wiki/Weekly_Shonen_Jump_April_2015_membership_promotional_card
# JUMP-EN072
# JUMP
# 10
# https://yugipedia.com/wiki/Crossed_Souls
# CROS-EN000
# CROS
# 11
# https://yugipedia.com/wiki/Saber_Force_Starter_Deck
# YS15-ENF00
# YS15
# 12
# https://yugipedia.com/wiki/Dark_Legion_Starter_Deck
# YS15-ENL00
# YS15
# 13
# https://yugipedia.com/wiki/Astral_Pack_Seven
# AP07-EN001
# AP07
# 14
# https://yugipedia.com/wiki/Star_Pack_ARC-V
# SP15-EN001
# SP15
# 15
# https://yugipedia.com/wiki/Duelist_Pack:_Battle_City
# DPBC-EN001
# DPBC
# 16
# https://yugipedia.com/wiki/Weekly_Shonen_Jump_July_2015_membership_promotional_card
# JUMP-EN073
# JUMP
# 17
# https://yugipedia.com/wiki/Crossed_Souls:_Advance_Edition
# CROS-ENAE1
# CROS
# 18
# https://yugipedia.com/wiki/Dragons_of_Legend_2
# DRL2-EN001
# DRL2
# 19
# https://yugipedia.com/wiki/Clash_of_Rebellions
# CORE-EN000
# CORE
# 20
# https://yugipedia.com/wiki/Synchron_Extreme_Structure_Deck
# SDSE-EN001
# SDSE
# 21
# https://yugipedia.com/wiki/Yu-Gi-Oh!_World_Championship_2015_prize_cards
# 2015-EN001
# 2015
# 22
# https://yugipedia.com/wiki/Yu-Gi-Oh!_World_Championship_2015_attendance_cards
# 2015-JPP01
# 2015
# 23
# https://yugipedia.com/wiki/Yu-Gi-Oh!_ZEXAL_Volume_7_promotional_card
# YZ07-EN001
# YZ07
# 24
# https://yugipedia.com/wiki/Yu-Gi-Oh!_Championship_Series_2015_Prize_Card
# YCSW-EN008
# YCSW
# 25
# https://yugipedia.com/wiki/2015_Mega-Tin_Mega_Pack
# MP15-EN001
# MP15
# 26
# https://yugipedia.com/wiki/High-Speed_Riders
# HSRD-EN001
# HSRD
# 27
# https://yugipedia.com/wiki/Yu-Gi-Oh!_5D%27s
# https://yugipedia.com/wiki/The_Lost_Art_Promotion_2020_J
# LART-EN022
# LART
# 26
# https://yugipedia.com/wiki/OTS_Tournament_Pack_14
# OP14-EN001
# OP14
# 27
# https://yugipedia.com/wiki/The_Lost_Art_Promotion_2020_M
# LART-EN025
# LART
# 28
# https://yugipedia.com/wiki/Structure_Deck:_Spirit_Charmers
# SDCH-ENT01
# SDCH
# 29
# https://yugipedia.com/wiki/Phantom_Rage
# PHRA-EN000
# PHRA
# 30
# https://yugipedia.com/wiki/Maximum_Gold
# MAGO-EN001
# MAGO
# 31
# https://yugipedia.com/wiki/Speed_Duel:_Battle_City_Box
# SBCB-ENS01
# SBCB
# 32
# https://yugipedia.com/wiki/Genesis_Impact
# GEIM-EN001
# GEIM
# 0
# https://yugipedia.com/wiki/Legendary_Duelists:_Season_2
# LDS2-EN015
# LDS2
# 1
# https://yugipedia.com/wiki/Blazing_Vortex
# BLVO-EN000
# BLVO
# 2
# https://yugipedia.com/wiki/OTS_Tournament_Pack_15
# OP15-EN001
# OP15
# 3
# https://yugipedia.com/wiki/Structure_Deck:_Freezing_Chains
# SDFC-EN001
# SDFC
# 4
# https://yugipedia.com/wiki/Ghosts_From_the_Past_(set)
# GFTP-EN001
# GFTP
# 5
# https://yugipedia.com/wiki/Ancient_Guardians
# ANGU-EN001
# ANGU
# 6
# https://yugipedia.com/wiki/Lightning_Overdrive
# LIOV-EN000
# LIOV
# 7
# https://yugipedia.com/wiki/OTS_Tournament_Pack_16
# OP16-EN001
# OP16
# 8
# https://yugipedia.com/wiki/Egyptian_God_Deck:_Slifer_the_Sky_Dragon
# EGS1-EN001
# EGS1
# 9
# https://yugipedia.com/wiki/Egyptian_God_Deck:_Obelisk_the_Tormentor
# EGO1-EN001
# EGO1
# 10
# https://yugipedia.com/wiki/King%27s_Court
# KICO-EN001
# KICO
# 11
# https://yugipedia.com/wiki/Dawn_of_Majesty
# DAMA-EN000
# DAMA
# 12
# https://yugipedia.com/wiki/2021_Tin_of_Ancient_Battles
# MP21-EN001
# MP21
# 13
# https://yugipedia.com/wiki/OTS_Tournament_Pack_17
# OP17-EN001
# OP17
# 14
# https://yugipedia.com/wiki/Structure_Deck:_Cyber_Strike
# SDCS-EN001
# SDCS
# 15
# https://yugipedia.com/wiki/Legendary_Duelists:_Synchro_Storm
# LED8-EN001
# LED8
# 16
# https://yugipedia.com/wiki/Burst_of_Destiny
# BODE-EN000
# BODE
# 17
# https://yugipedia.com/wiki/Maximum_Gold:_El_Dorado
# MGED-EN001
# MGED
# 18
# https://yugipedia.com/wiki/Brothers_of_Legend
# BROL-EN000
# BROL
# 19
# https://yugipedia.com/wiki/The_Grand_Creators
# GRCR-EN001
# GRCR
# 20
# https://yugipedia.com/wiki/Battle_of_Chaos
# 25TH-EN001
# BACH
# 21
# https://yugipedia.com/wiki/OTS_Tournament_Pack_18
# OP18-EN001
# OP18

# %%
for year in years_2020_2022:
    df = set_code(year_df)
    df = df.drop_duplicates()
    df = df.reset_index(drop = True)
    df = df.drop(columns = 'index')

    sets_done_index = []

    #Cards not on sale removed, special edition removed as Cardmarket covers them anyway.
    for i in range(0, len(df)):
        if ('KC Grand Tournament' in list(df['Set Name'])[i]) or ('Japan Championship' in list(df['Set Name'])[i]) or ('Masterpiece Series' in list(df['Set Name'])[i]) or ('Premiere! promotional card' in list(df['Set Name'])[i]) or ('Sneak Peek Participation Card' in list(df['Set Name'])[i]) or ('Special Edition' in list(df['Set Name'])[i]) or ('Super Edition' in list(df['Set Name'][i])):
            sets_done_index.append(i)


    df = df.drop(sets_done_index)
    df = df.reset_index(drop = True)

    
    set_code_dfs.append(set_code_df)
    print('done')

# %%
# year_set_dict['2002'], year_set_dict['2003'],  year_set_dict['2004'] gives us the right thing
# Out:
#                                              Set Name  \
# 0                    Legend of Blue Eyes White Dragon
# 1       Yu-Gi-Oh! Dark Duel Stories promotional cards
# 2                                  Starter Deck: Yugi
# 3                                 Starter Deck: Kaiba
# 4                                       Metal Raiders
# 5                         Tournament Pack: 1st Season
# 6                                         Spell Ruler
# 7                         Tournament Pack: 2nd Season
# 8                   Booster Pack Collectors Tins 2002
# 9   Yu-Gi-Oh! The Eternal Duelist Soul promotional...
# 10                                  Pharaoh's Servant
# 11  Yu-Gi-Oh! Forbidden Memories Premium Edition p...
# 12       Shonen Jump Vol. 1, Issue 1 promotional card
# 13                       McDonald's Promotional Cards
#
#                                         Yugipedia url
# 0   https://yugipedia.com/wiki/Legend_of_Blue_Eyes...
# 1   https://yugipedia.com/wiki/Yu-Gi-Oh!_Dark_Duel...
# 2       https://yugipedia.com/wiki/Starter_Deck:_Yugi
# 3      https://yugipedia.com/wiki/Starter_Deck:_Kaiba
# 4            https://yugipedia.com/wiki/Metal_Raiders
# 5   https://yugipedia.com/wiki/Tournament_Pack:_1s...
# 6              https://yugipedia.com/wiki/Spell_Ruler
# 7   https://yugipedia.com/wiki/Tournament_Pack:_2n...
# 8   https://yugipedia.com/wiki/Booster_Pack_Collec...
# 9   https://yugipedia.com/wiki/Yu-Gi-Oh!_The_Etern...
# 10     https://yugipedia.com/wiki/Pharaoh%27s_Servant
# 11  https://yugipedia.com/wiki/Yu-Gi-Oh!_Forbidden...
# 12  https://yugipedia.com/wiki/Shonen_Jump_Vol._1,...
# 13  https://yugipedia.com/wiki/McDonald%27s_Promot...

# %%
year_set_dict['2016']
# Out:
#                                              Set Name  \
# 0    Breakers of Shadow Sneak Peek Participation Card
# 1                                      Demo Deck 2016
# 2                                  Breakers of Shadow
# 3   Weekly Shonen Jump January 2016 membership pro...
# 4                  Emperor of Darkness Structure Deck
# 5                                        Wing Raiders
# 6                 Breakers of Shadow: Special Edition
# 7           Yu-Gi-Oh! ZEXAL Volume 8 promotional card
# 8                         Premium Gold: Infinite Gold
# 9                               OTS Tournament Pack 1
# 10           Yu-Gi-Oh! 5D's Volume 9 promotional card
# 11                                    Millennium Pack
# 12  Weekly Shonen Jump April 2016 membership promo...
# 13    Shining Victories Sneak Peek Participation Card
# 14                                  Shining Victories
# 15                                 Starter Deck: Yuya
# 16                 Shining Victories: Special Edition
# 17           WSJ Jump Pack Fall 2016 promotional card
# 18  Weekly Shonen Jump July 2016 membership promot...
# 19            Rise of the True Dragons Structure Deck
# 37  https://yugipedia.com/wiki/Invasion:_Vengeance...

# %%
url = "https://yugipedia.com/wiki/Order_of_Set_Release#2022_2"
result = requests.get(url)
src = result.content
soup = BeautifulSoup(src, 'html.parser')

TCG_set_name = []
TCG_set_yugipedia_link = []

for TCG_card_set in soup.find_all("ul")[339:576]:
    set_names = TCG_card_set.find_all('a')
    for set_name in set_names:
        TCG_set_name.append(set_name.text)
        TCG_set_yugipedia_link.append('https://yugipedia.com' + set_name.attrs['href'])
        
df = pd.DataFrame({"Set Name" : TCG_set_name, "Yugipedia url" : TCG_set_yugipedia_link})

df = df.drop_duplicates()
df = df.reset_index()
df = df.drop(columns = 'index')

sets_done_index = []

#Cards not on sale removed, special edition removed as Cardmarket covers them anyway.
for i in range(0, len(df)):
    if ('KC Grand Tournament' in list(df['Set Name'])[i]) or ('Japan Championship' in list(df['Set Name'])[i]) or ('Masterpiece Series' in list(df['Set Name'])[i]) or ('Premiere! promotional card' in list(df['Set Name'])[i]) or ('Sneak Peek Participation Card' in list(df['Set Name'])[i]) or ('Special Edition' in list(df['Set Name'])[i]) or ('Super Edition' in list(df['Set Name'][i])):
        sets_done_index.append(i)


df = df.drop(sets_done_index)
df = df.iloc[::-1]
df = df.reset_index()

#All LART but one removed
lost_art_index = []
for i in range(41, len(df)):
    if 'The Lost Art Promotion' in list(df['Set Name'])[i]:
        
        lost_art_index.append(i)

df = df.drop(lost_art_index)
df = df.drop(columns = 'index')
df = df.reset_index()
df = df.drop(columns = 'index')

# %%
set_code_dfs = []
for year_df in dfs:
    set_code_df = set_code(year_df)
    set_code_dfs.append(set_code_df)
    print('done')
# Out:
# 0
# https://yugipedia.com/wiki/OTS_Tournament_Pack_6
# OP06-EN001
# OP06
# 1
# https://yugipedia.com/wiki/Kaiba%27s_Collector_Box
# KACB-EN001
# KACB
# 2
# https://yugipedia.com/wiki/Spirit_Warriors
# SPWA-EN001
# SPWA
# 3
# https://yugipedia.com/wiki/Structure_Deck:_Cyberse_Link
# SDCL-EN001
# SDCL
# 4
# https://yugipedia.com/wiki/Circuit_Break
# CIBR-EN000
# CIBR
# 5
# https://yugipedia.com/wiki/Legendary_Dragon_Decks
# LEDD-ENA00
# LEDD
# 6
# https://yugipedia.com/wiki/Yugi%27s_Collector_Box
# YUCB-EN001
# YUCB
# 7
# https://yugipedia.com/wiki/Legendary_Duelists
# LEDU-EN000
# LEDU
# 8
# https://yugipedia.com/wiki/Yu-Gi-Oh!_ARC-V_Volume_2_promotional_card
# YA02-JP001
# YA02
# 9
# https://yugipedia.com/wiki/Yu-Gi-Oh!_Championship_Series_2017_prize_card
# YCSW-EN010
# YCSW
# 10
# https://yugipedia.com/wiki/2017_Mega-Tin_Mega_Pack
# MP17-EN001
# MP17
# 11
# https://yugipedia.com/wiki/2017_Mega-Tins
# CT14-EN001
# CT14
# 12
# https://yugipedia.com/wiki/Yu-Gi-Oh!_World_Championship_2017_prize_cards
# 2017-EN001
# 2017
# 13
# https://yugipedia.com/wiki/OTS_Tournament_Pack_5
# OP05-EN001
# OP05
# 14
# https://yugipedia.com/wiki/Code_of_the_Duelist
# COTD-EN000
# COTD
# 15
# https://yugipedia.com/wiki/Yu-Gi-Oh!_
# OP15
# 17
# https://yugipedia.com/wiki/Blazing_Vortex
# BLVO-EN000
# BLVO
# 18
# https://yugipedia.com/wiki/Legendary_Duelists:_Season_2
# LDS2-EN015
# LDS2
# done
# 0
# https://yugipedia.com/wiki/Structure_Deck:_Legend_of_the_Crystal_Beasts
# SDCB-EN001
# SDCB
# 1
# https://yugipedia.com/wiki/Speed_Duel_Tournament_Pack_4
# STP4-ENS01
# STP4
# 2
# https://yugipedia.com/wiki/2022_Tin_of_the_Pharaoh%27s_Gods
# MP22-EN001
# MP22
# 3
# https://yugipedia.com/wiki/Yu-Gi-Oh!_Championship_Series_2022_prize_card
# YCSW-EN013
# YCSW
# 4
# https://yugipedia.com/wiki/Tactical_Masters
# TAMA-EN001
# TAMA
# 5
# https://yugipedia.com/wiki/Power_of_the_Elements
# POTE-EN000
# POTE
# 6
# https://yugipedia.com/wiki/Legendary_Duelists:_Season_3
# LDS3-EN009
# LDS3
# 7
# https://yugipedia.com/wiki/Legendary_Duelists:_Duels_From_the_Deep
# LED9-EN000
# LED9
# 8
# https://yugipedia.com/wiki/OTS_Tournament_Pack_19
# OP19-EN001
# OP19
# 9
# https://yugipedia.com/wiki/Dimension_Force
# DIFO-EN000
# DIFO
# 10
# https://yugipedia.com/wiki/Ghosts_From_the_Past:_The_2nd_Haunting
# GFP2-EN001
# GFP2
# 11
# https://yugipedia.com/wiki/Structure_Deck:_Albaz_Strike
# SDAZ-EN001
# SDAZ
# 12
# https://yugipedia.com/wiki/Trials_of_the_Pharaoh_-_Speed_Duel_GX:_Duel_Academy_Box_promotional_card
# OPTP-EN004
# OPTP
# 13
# https://yugipedia.com/wiki/Speed_Duel_Tournament_Pack_3
# STP3-ENS01
# STP3
# 14
# https://yugipedia.com/wiki/Speed_Duel_Box_featuring_Yu-Gi-Oh!_GX
# SGX1-ENA06
# SGX1
# 15
# https://yugipedia.com/wiki/Hidden_Arsenal:_Chapter_1
# HAC1-EN172
# HAC1
# 16
# https://yugipedia.com/wiki/OTS_Tournament_Pack_18
# OP18-EN001
# OP18
# 17
# https://yugipedia.com/wiki/Battle_of_Chaos
# 25TH-EN001
# BACH
# 18
# https://yugipedia.com/wiki/The_Grand_Creators
# GRCR-EN001
# GRCR
# done
# <ipython-input-61-76577e83c0e2>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['Set Code'] = code_list

# %%
sets_each_year = []
for year_df in set_code_dfs:
    sets = year_df['Set Code']
    sets_each_year.append(list(sets))
    
sets_year_dict = {[str(2017 + i) for i in range(0,6)][i] : sets_each_year[i] for i in range(0,6)}

# %%
print(sets_year_dict)
# Out:
# {'2017': ['OP06', 'KACB', 'SPWA', 'SDCL', 'CIBR', 'LEDD', 'YUCB', 'LEDU', 'YA02', 'YCSW', 'MP17', 'CT14', '2017', 'OP05', 'COTD', 'TKN4', 'YS17', 'BLLR', 'JUMP', 'MVPC', 'PEVO', 'DPDG', 'MACR', 'SR04', 'SR03', 'YA01', 'DUSA', 'SP17', 'FUEN', 'RATE', 'SDPD', 'MVP1'], '2018': ['OP09', 'HISU', 'YA04', 'SR07', 'SOFU', 'LEHD', 'LED3', 'MP18', 'CT15', 'OP08', 'SHVA', 'SDPL', 'CYHO', 'YS18', 'BLRR', 'FLOD', 'SR06', 'OP07', 'SP18', 'YUCB', 'LCKC', 'LC06', 'YA03', 'LED2', 'EXFO', 'SR05'], '2019': ['OP12', 'SBTK', 'SBTK', 'MYFI', 'CHIM', 'DUDE', 'STP2', 'LED5', 'AC19', 'YA06', 'MP19', 'TN19', 'YCSW', 'FIGA', 'LOD2', 'SDRR', '2019', 'SBSC', 'SS03', 'EVSD', 'RIRA', 'OP11', 'BLHR', 'JUMP', 'DEM5', 'SBAD', 'DANE', 'SR08', 'STP1', 'OP10', 'YDPR', 'DUPO', 'SBLS', 'INCH', 'YA05', 'SDSB', 'SAST', 'SS01', 'SS02', 'LED4', 'JMPS'], '2020': ['GEIM', 'SBCB', 'MAGO', 'PHRA', 'SDCH', 'OP14', 'LED7', 'DLCS', 'MP20', 'ROTD', 'BLAR', 'SDSA', 'LDS1', 'TOCH', 'YA07', 'SS04', 'SS05', 'ETCO', 'OP13', 'SR10', 'SESL', 'DUOV', 'SDSH', 'JMPS', 'IGAS', 'MVP1', 'LED6'], '2021': ['BROL', 'MGED', 'BODE', 'LED8', 'SDCS', 'OP17', 'MP21', 'DAMA', 'KICO', 'EGO1', 'EGS1', 'OP16', 'LIOV', 'ANGU', 'GFTP', 'SDFC', 'OP15', 'BLVO', 'LDS2'], '2022': ['SDCB', 'STP4', 'MP22', 'YCSW', 'TAMA', 'POTE', 'LDS3', 'LED9', 'OP19', 'DIFO', 'GFP2', 'SDAZ', 'OPTP', 'STP3', 'SGX1', 'HAC1', 'OP18', 'BACH', 'GRCR']}

# %%
for year in list(sets_year_dict.keys()):
    if not os.path.exists('cardmarket_data_by_year\{}'.format(year)):
        os.makedirs('cardmarket_data_by_year\{}'.format(year))

# %%
for year in list(sets_year_dict.keys()):
    #get the sets for each year
    for card_set in sets_year_dict[year]:
        if (os.path.exists('Cardmarket data\{}'.format(card_set))) and (not os.path.exists('cardmarket_data_by_year\{}\{}'.format(year, card_set))):
            shutil.copytree('Cardmarket data\{}'.format(card_set),'cardmarket_data_by_year\{}\{}'.format(year, card_set))

# %%
print(set_code_dfs[5])
# Out:
#                                              Set Name  \
# 0        Structure Deck: Legend of the Crystal Beasts
# 1                        Speed Duel Tournament Pack 4
# 2                      2022 Tin of the Pharaoh's Gods
# 3       Yu-Gi-Oh! Championship Series 2022 prize card
# 4                                    Tactical Masters
# 5                               Power of the Elements
# 6                        Legendary Duelists: Season 3
# 7             Legendary Duelists: Duels From the Deep
# 8                              OTS Tournament Pack 19
# 9                                     Dimension Force
# 10             Ghosts From the Past: The 2nd Haunting
# 11                       Structure Deck: Albaz Strike
# 12  Trials of the Pharaoh - Speed Duel GX: Duel Ac...
# 13                       Speed Duel Tournament Pack 3
# 14              Speed Duel Box featuring Yu-Gi-Oh! GX
# 15                          Hidden Arsenal: Chapter 1
# 16                             OTS Tournament Pack 18
# 17                                    Battle of Chaos
# 18                                 The Grand Creators
#
#                                         Yugipedia url Set Code
# 0   https://yugipedia.com/wiki/Structure_Deck:_Leg...     SDCB
# 1   https://yugipedia.com/wiki/Speed_Duel_Tourname...     STP4
# 2   https://yugipedia.com/wiki/2022_Tin_of_the_Pha...     MP22
# 3   https://yugipedia.com/wiki/Yu-Gi-Oh!_Champions...     YCSW
# 4         https://yugipedia.com/wiki/Tactical_Masters     TAMA
# 5    https://yugipedia.com/wiki/Power_of_the_Elements     POTE
# 6   https://yugipedia.com/wiki/Legendary_Duelists:...     LDS3
# 7   https://yugipedia.com/wiki/Legendary_Duelists:...     LED9
# 8   https://yugipedia.com/wiki/OTS_Tournament_Pack_19     OP19
# 9          https://yugipedia.com/wiki/Dimension_Force     DIFO
# 10  https://yugipedia.com/wiki/Ghosts_From_the_Pas...     GFP2
# 11  https://yugipedia.com/wiki/Structure_Deck:_Alb...     SDAZ
# 12  https://yugipedia.com/wiki/Trials_of_the_Phara...     OPTP
# 13  https://yugipedia.com/wiki/Speed_Duel_Tourname...     STP3
# 14  https://yugipedia.com/wiki/Speed_Duel_Box_feat...     SGX1
# 15  https://yugipedia.com/wiki/Hidden_Arsenal:_Cha...     HAC1
# 16  https://yugipedia.com/wiki/OTS_Tournament_Pack_18     OP18
# 17         https://yugipedia.com/wiki/Battle_of_Chaos     BACH
# 18      https://yugipedia.com/wiki/The_Grand_Creators     GRCR

# %%
df_2020_2022 = set_code(df[0:65])
# Out:
# 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     350                 try:
# --> 351                     return self._range.index(new_key)
#     352                 except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-897403f4812c> in <module>
# ----> 1 df_2020_2022 = set_code(df[0:65])
#
# <ipython-input-61-76577e83c0e2> in set_code(dataframe)
#       7     for i in range(0,len(dataframe)):
#       8         print(i)
# ----> 9         url = dataframe['Yugipedia url'][i]
#      10         print(url)
#      11         result = requests.get(url)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     851
#     852         elif key_is_scalar:
# --> 853             return self._get_value(key)
#     854
#     855         if is_hashable(key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#     959
#     960         # Similar to Index.get_value, but we do not fall back to positional
# --> 961         loc = self.index.get_loc(label)
#     962         return self.index._get_values_for_loc(self, loc, label)
#     963
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     351                     return self._range.index(new_key)
#     352                 except ValueError as err:
# --> 353                     raise KeyError(key) from err
#     354             raise KeyError(key)
#     355         return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 0

# %%
# Out:
# 0
# done
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-ab618cfae204> in <module>
#       1 set_code_dfs = []
#       2 for df in dfs:
# ----> 3     print(dfs.index(df))
#       4     set_code_df = set_code(df)
#       5     set_code_dfs.append(set_code_df)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1440     @final
#    1441     def __nonzero__(self):
# -> 1442         raise ValueError(
#    1443             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1444             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
print(len(df))
# Out:
# 672

# %%
#0-18 is 2022
#19-37 is 2021
#38-64 is 2020
#65-105 is 2019
#106-131 is 2018
#132-163 is 2017

# %%
df.head(19)
# Out:
#                                              Set Name  \
# 0        Structure Deck: Legend of the Crystal Beasts
# 1                        Speed Duel Tournament Pack 4
# 2                      2022 Tin of the Pharaoh's Gods
# 3       Yu-Gi-Oh! Championship Series 2022 prize card
# 4                                    Tactical Masters
# 5                               Power of the Elements
# 6                        Legendary Duelists: Season 3
# 7             Legendary Duelists: Duels From the Deep
# 8                              OTS Tournament Pack 19
# 9                                     Dimension Force
# 10             Ghosts From the Past: The 2nd Haunting
# 11                       Structure Deck: Albaz Strike
# 12  Trials of the Pharaoh - Speed Duel GX: Duel Ac...
# 84  https://yugipedia.com/wiki/Speed_Duel:_Attack_...
# 85           https://yugipedia.com/wiki/Dark_Neostorm
# 86  https://yugipedia.com/wiki/Structure_Deck:_Ord...
# 87  https://yugipedia.com/wiki/Speed_Duel_Tourname...
# 88  https://yugipedia.com/wiki/OTS_Tournament_Pack_10
# 89  https://yugipedia.com/wiki/Yu-Gi-Oh!_Day_April...

# %%
df.iloc[89:100]
# Out:
#                                           Set Name  \
# 89       Yu-Gi-Oh! Day April 2019 promotional card
# 90                                      Duel Power
# 91                 Speed Duel: Arena of Lost Souls
# 92                            The Infinity Chasers
# 93       Yu-Gi-Oh! ARC-V Volume 5 promotional card
# 94                      Structure Deck: Soulburner
# 95                                   Savage Strike
# 96       Speed Duel Starter Decks: Destiny Masters
# 97  Speed Duel Starter Decks: Duelists of Tomorrow
# 98         Legendary Duelists: Sisters of the Rose
# 99      WSJ Jump Pack Spring 2019 promotional card
#
#                                         Yugipedia url
# 89  https://yugipedia.com/wiki/Yu-Gi-Oh!_Day_April...
# 90              https://yugipedia.com/wiki/Duel_Power
# 91  https://yugipedia.com/wiki/Speed_Duel:_Arena_o...
# 92    https://yugipedia.com/wiki/The_Infinity_Chasers
# 93  https://yugipedia.com/wiki/Yu-Gi-Oh!_ARC-V_Vol...
# 94  https://yugipedia.com/wiki/Structure_Deck:_Sou...
# 95           https://yugipedia.com/wiki/Savage_Strike
# 96  https://yugipedia.com/wiki/Speed_Duel_Starter_...
# 97  https://yugipedia.com/wiki/Speed_Duel_Starter_...
# 98  https://yugipedia.com/wiki/Legendary_Duelists:...
# 99  https://yugipedia.com/wiki/WSJ_Jump_Pack_Sprin...

# %%
for i in range(1,2):
    print(df['Set Name'][i])
    url = df['Yugipedia url'][i]
    card_set = TCG_set(url)
    if card_set.set_code in ['POTE', 'MP22', 'TAMA', 'LDS3', 'DIFO', 'YCSW', 'OPTP', 'OP18']:
        print('Already have data for ' + str(card_set.set_code))
        continue
    else:
        card_set.cardmarket_price_last_30_days(0)
# Out:
# Speed Duel Tournament Pack 4
# Already have Cardmarket data\STP4
# No chart data for STP4-001 Giant Rat
# No chart data for STP4-002 Old Vindictive Magician
# No chart data for STP4-003 Dark Magic Curtain
# No chart data for STP4-004 Creature Swap
# No chart data for STP4-005 Mind Crush
# No chart data for STP4-006 Jack's Knight
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-8aceafa89025> in <module>
#       7         continue
#       8     else:
# ----> 9         card_set.cardmarket_price_last_30_days(0)
#
# ~\Documents\YUGIOH-Price-Predictor-master\MP22\TCG_set_V4.py in cardmarket_price_last_30_days(self, set_number)
#     185             #Parsing the site for the data from the chart (last two weeks of avg sale price in Euros)
#     186             url = list(df['Cardmarket UK Links'])[j]
# --> 187             result = requests.get(url)
#     188             src = result.content
#     189             soup = BeautifulSoup(src, 'html.parser')
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     675             # Redirect resolving generator.
#     676             gen = self.resolve_redirects(r, request, **kwargs)
# --> 677             history = [resp for resp in gen]
#     678         else:
#     679             history = []
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in <listcomp>(.0)
#     675             # Redirect resolving generator.
#     676             gen = self.resolve_redirects(r, request, **kwargs)
# --> 677             history = [resp for resp in gen]
#     678         else:
#     679             history = []
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     235             else:
#     236
# --> 237                 resp = self.send(
#     238                     req,
#     239                     stream=stream,
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~\Anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\Anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
for i in range(37,38):
    print(df['Set Name'][i])
    url = df['Yugipedia url'][i]
    card_set = TCG_set(url)
    if card_set.set_code in []:
        print('Already have data for ' + str(card_set.set_code))
        continue
    else:
        card_set.cardmarket_prices_update(0)
# Out:
# Legendary Duelists: Season 2
# LDS2-001 Blue-Eyes White Dragon (V.1 - Ultra Rare)
# LDS2-001 Blue-Eyes White Dragon (V.2 - Ultra Rare)
# LDS2-001 Blue-Eyes White Dragon (V.3 - Ultra Rare)
# LDS2-001 Blue-Eyes White Dragon (V.4 - Ultra Rare)
# LDS2-002 Kaibaman
# LDS2-003 Decoy Dragon
# LDS2-004 The White Stone of Legend
# LDS2-005 Malefic Blue-Eyes White Dragon
# LDS2-006 Maiden with Eyes of Blue
# LDS2-007 Priestess with Eyes of Blue
# LDS2-008 Blue-Eyes Alternative White Dragon (V.1 - Ultra Rare)
# LDS2-008 Blue-Eyes Alternative White Dragon (V.2 - Ultra Rare)
# LDS2-008 Blue-Eyes Alternative White Dragon (V.3 - Ultra Rare)
# LDS2-008 Blue-Eyes Alternative White Dragon (V.4 - Ultra Rare)
# LDS2-009 Dragon Spirit of White
# LDS2-010 Protector with Eyes of Blue
# LDS2-011 Sage with Eyes of Blue (V.1 - Ultra Rare)
# LDS2-011 Sage with Eyes of Blue (V.2 - Ultra Rare)
# LDS2-011 Sage with Eyes of Blue (V.3 - Ultra Rare)
# LDS2-011 Sage with Eyes of Blue (V.4 - Ultra Rare)
# LDS2-012 Master with Eyes of Blue
# LDS2-013 The White Stone of Ancients (V.1 - Ultra Rare)
# LDS2-013 The White Stone of Ancients (V.2 - Ultra Rare)
# LDS2-013 The White Stone of Ancients (V.3 - Ultra Rare)
# LDS2-013 The White Stone of Ancients (V.4 - Ultra Rare)
# LDS2-014 Blue-Eyes Solid Dragon (V.1 - Ultra Rare)
# LDS2-014 Blue-Eyes Solid Dragon (V.2 - Ultra Rare)
# LDS2-014 Blue-Eyes Solid Dragon (V.3 - Ultra Rare)
# LDS2-014 Blue-Eyes Solid Dragon (V.4 - Ultra Rare)
# LDS2-015 Blue-Eyes Abyss Dragon
# LDS2-016 Blue-Eyes Chaos MAX Dragon (V.1 - Ultra Rare)
# LDS2-016 Blue-Eyes Chaos MAX Dragon (V.2 - Ultra Rare)
# LDS2-016 Blue-Eyes Chaos MAX Dragon (V.3 - Ultra Rare)
# LDS2-016 Blue-Eyes Chaos MAX Dragon (V.4 - Ultra Rare)
# LDS2-017 Blue-Eyes Chaos Dragon
# LDS2-018 Blue-Eyes Ultimate Dragon (V.1 - Ultra Rare)
# LDS2-018 Blue-Eyes Ultimate Dragon (V.2 - Ultra Rare)
# LDS2-018 Blue-Eyes Ultimate Dragon (V.3 - Ultra Rare)
# LDS2-018 Blue-Eyes Ultimate Dragon (V.4 - Ultra Rare)
# LDS2-019 Blue-Eyes Twin Burst Dragon (V.1 - Ultra Rare)
# LDS2-019 Blue-Eyes Twin Burst Dragon (V.2 - Ultra Rare)
# LDS2-121 Super Express Bullet Train (V.4 - Ultra Rare)
# LDS2-122 Flying Pegasus Railroad Stampede
# LDS2-123 Number 81 Superdreadnought Rail Cannon Super Dora
# LDS2-124 Superdreadnought Rail Cannon Juggernaut Liebe
# LDS2-125 Urgent Schedule
# LDS2-126 Barrage Blast
# LDS2-127 Lunalight Emerald Bird
# LDS2-128 Lunalight Yellow Marten
# LDS2-129 Lunalight Sabre Dancer
# LDS2-130 Lunalight Fusion
# LDS2-131 Lunalight Serenade Dance

# %%
#get rid of YCSW for all but 2022 prize card.

# %%
#need to go back to Hidden Arsenal coz it has a lot of cards in two rarities - this is a lost cause.

#Sort the Arc-V manga cards and the SJ promo card.
#last two cards of tournament pack 13
#MVP1 - secret edition name causing issues.
#SBTK missing a card
#AC19
#LOD2
#Speed Duel Starter Decks: Ultimate Predators
#check speed duel promo cards
#speed duel demo deck
#SBSC
#SBAD
#Speed Duel starter deck - destiny masters

# %%
# Out:
# Already have Cardmarket data\MP20

# %%
print(card_set.cardmarket_set_content)
# Out:
#                  Card Name Card Number       Rarity  \
# 0         Danger! Ogopogo!         001  Secret Rare
# 1      Salamangreat Wolvie         002       Common
# 2       Salamangreat Parro         003       Common
# 3       Salamangreat Foxer         004       Common
# 4        Speedburst Dragon         005       Common
# ..                     ...         ...          ...
# 244     Magicalized Fusion         245  Secret Rare
# 245         Successor Soul         246   Ultra Rare
# 246      Strength in Unity         247   Ultra Rare
# 247        Destined Rivals         248   Ultra Rare
# 248  Red-Eyes Dark Dragoon         249   Ultra Rare
#
#                                       Cardmarket Links  \
# 0    https://www.cardmarket.com//en/YuGiOh/Products...
# 1    https://www.cardmarket.com//en/YuGiOh/Products...
# 2    https://www.cardmarket.com//en/YuGiOh/Products...
# 3    https://www.cardmarket.com//en/YuGiOh/Products...
# 4    https://www.cardmarket.com//en/YuGiOh/Products...
# ..                                                 ...
# 244  https://www.cardmarket.com//en/YuGiOh/Products...
# 245  https://www.cardmarket.com//en/YuGiOh/Products...
# 246  https://www.cardmarket.com//en/YuGiOh/Products...
# 247  https://www.cardmarket.com//en/YuGiOh/Products...
# 248  https://www.cardmarket.com//en/YuGiOh/Products...
#
#                                    Cardmarket UK Links
# 0    https://www.cardmarket.com//en/YuGiOh/Products...
# 1    https://www.cardmarket.com//en/YuGiOh/Products...
# 2    https://www.cardmarket.com//en/YuGiOh/Products...
# 3    https://www.cardmarket.com//en/YuGiOh/Products...
# 4    https://www.cardmarket.com//en/YuGiOh/Products...
# ..                                                 ...
# 244  https://www.cardmarket.com//en/YuGiOh/Products...
# 245  https://www.cardmarket.com//en/YuGiOh/Products...
# 246  https://www.cardmarket.com//en/YuGiOh/Products...
# 247  https://www.cardmarket.com//en/YuGiOh/Products...
# 248  https://www.cardmarket.com//en/YuGiOh/Products...
#
# [249 rows x 5 columns]

# %%
from TCG_set_V3 import TCG_set

card_set = TCG_set('https://yugipedia.com/wiki/The_Lost_Art_Promotion_2020_M')
#card_set.cardmarket_price_last_30_days(0)

# %%
print(card_set.cardmarket_set_content)
